# %% [markdown]
# ## Import libraries

# %%
# import requests and json
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Call NYTimes API

# %%
#API key and setting for the community api
#https://developer.nytimes.com/docs/community-api-product/1/routes/user-content/url.json/get
api_key = "***************"
article_url = "https://www.nytimes.com/2020/10/26/opinion/qanon-conspiracy-donald-trump.html?searchResultPosition=4"
sort = "newest"

# %%
# show the API url with all the settings listed out
api_url = (f"https://api.nytimes.com/svc/community/v3/user-content/url.json?api-key={api_key}&url={article_url}&offset=0")

#test to see if api url is correct
print(api_url)
# Out:
# https://api.nytimes.com/svc/community/v3/user-content/url.json?api-key=03Q77oAuM8UocuAmO9MwGeuV65h1KQeD&url=https://www.nytimes.com/2020/10/26/opinion/qanon-conspiracy-donald-trump.html?searchResultPosition=4&offset=0

# %%
# calling the API with requests
response = requests.get(api_url)

# creating a variable called data to hold the json formatted result
data = response.json()

data
# Out:
# {'debug': {'version': 4, 'nyt-com-shim': True},
#  'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'results': {'callerID': None,
#   'api_timestamp': '1606238753',
#   'comments': [{'commentID': 109814207,
#     'status': 'approved',
#     'commentSequence': 109814207,
#     'userID': 56748238,
#     'userDisplayName': 'JoeG',
#     'userLocation': 'Houston',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "Speaking in codes happens in countries losing grip on their ability to speak freely. People living in fear.\n\nBeing from NYC it was urban legend that all pizza parlors were owned and run by the mafia. When a character like Alex Jones says a child sex ring is being run out of a pizzeria, wht was he implying? Then the Epstein/Maxwell story broke. They did it all on their own? Were they the Lizard People From the Fifth Dimension Alex Jones connected to the pizzeria? \n\nThere are busts every year in Houston of pedophiles. Nearly every law enforcement organization is involved from the Houston police to the Dept of Homeland Security. It is described as a hub for sex trafficking. What exactly does that mean? The news tells us about the arrest but we are never the whole picture. How many hubs exist? Who is involved? Why do we have to go to alternate media to find remnants of the truth?\n\nInternational Pedophile rings don't  exist do they? And the rich would never do nothing so disgusting? You'd have to be a paranoid fool to believe such things. Prince Andrew and Bill Clinton? Only haters would say anything bad about them.\n\nThe nytimes usually doesn't print post  like this. It' was fun trying though.",
#     'createDate': '1603753124',
#     'updateDate': '1604006972',
#     'approveDate': '1603767563',
#     'recommendations': 9,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814207',
#     'isAnonymous': False},
#    {'commentID': 109815040,
#     'status': 'approved',
#     'commentSequence': 109815040,
#     'userID': 33897091,
#     'userDisplayName': 'kelleysh',
#     'userLocation': 'New Mexico',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Noam Chomsky? That one photo colors your entire report as sloppy.',
#     'createDate': '1603757833',
#     'updateDate': '1603824880',
#     'approveDate': '1603767563',
#     'recommendations': 3,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109815040',
#     'isAnonymous': False},
#    {'commentID': 109812712,
#     'status': 'approved',
#     'commentSequence': 109812712,
#     'userID': 3233383,
#     'userDisplayName': 'JB',
#     'userLocation': 'Carlsbad',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Maybe "Q" is actually a Russian disinformation campaign.',
#     'createDate': '1603745916',
#     'updateDate': '1604983150',
#     'approveDate': '1603767562',
#     'recommendations': 12,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109812712',
#     'isAnonymous': False},
#    {'commentID': 109814507,
#     'status': 'approved',
#     'commentSequence': 109814507,
#     'userID': 75998677,
#     'userDisplayName': 'dave beemon',
#     'userLocation': 'Boston',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/cropped-c77c0010a811db7a87b2b89a319553a706ac98a6824e4aef36953cbb5e86cb91.jpg',
#     'commentTitle': '<br\\//>',
#     'commentBody': "I guess the German's fell for the line that Jews were eating babies, and the economic metrics are similar, a lot of desperate poor people and a few rich people controlling all the money. So Donald gets it into his head from one of his sociopathic advisors that he should stick with QAnon. It has legs! \n\nI don't think so. We're not 1933 Germans. We're a bunch of diverse people who will withstand the defilement of our country. We will accept our responsibilities to the world that we have not always been kind to. We need to grow up.",
#     'createDate': '1603754676',
#     'updateDate': '1603842469',
#     'approveDate': '1603767562',
#     'recommendations': 8,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814507',
#     'isAnonymous': False},
#    {'commentID': 109814570,
#     'status': 'approved',
#     'commentSequence': 109814570,
#     'userID': 67289665,
#     'userDisplayName': 'Bach',
#     'userLocation': 'Grand Rapids, MI',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/uncropped-9c852eae277d245efb5e5642d12da8aad86d4328ce28ce1ddca04d6f9e76fb0d.jpg',
#     'commentTitle': '<br\\//>',
#     'commentBody': 'QAnon, Trump, McConnell, and Amy Coney Barrett. Let’s see hear...\n\nAn ancient alien race’s artifact is found by Fred Trump when fighting child brain-sucking Democrat communists in 1953. His son used the very powerful talisman to summon Amy Coney Barrett from McConnell’s horse farm in Kentucky to become the first High Priestess of the Supreme Court.\n\nIf you say it over and over, it almost makes sense. I’ll entertain streaming offers.\n\nI’m humbled by the Old Testament prophecy of comedian Ron White... You just can’t fix stupid!',
#     'createDate': '1603755069',
#     'updateDate': '1603798350',
#     'approveDate': '1603767562',
#     'recommendations': 5,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814570',
#     'isAnonymous': False},
#    {'commentID': 109814602,
#     'status': 'approved',
#     'commentSequence': 109814602,
#     'userID': 73607049,
#     'userDisplayName': 'oldBassGuy',
#     'userLocation': 'mass',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "Go for the jocular (not jugular) vein. Not sure who to attribute this to (Barney Frank?)\n\nOr as Jefferson put it:\n  ridicule is the only weapon which can be used against unintelligible propositions. ideas must be distinct before reason can act upon them; ...\n\nI just  double down on any QAnon-type  stupidity that happens in my presence. Eg Rush's idiotic Obama is a Islamo-fascist.",
#     'createDate': '1603755239',
#     'updateDate': '1603927552',
#     'approveDate': '1603767562',
#     'recommendations': 3,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814602',
#     'isAnonymous': False},
#    {'commentID': 109813069,
#     'status': 'approved',
#     'commentSequence': 109813069,
#     'userID': 44479572,
#     'userDisplayName': 'Jono',
#     'userLocation': 'Tucson',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "I'm no Q supporter but what a waste of 10 minutes. Psycho gobbledygook. Never delves into what the Qanons say re: the pedo cult... it's just absurd... so, nothing there.  Pathetic!",
#     'createDate': '1603747512',
#     'updateDate': '1603853224',
#     'approveDate': '1603767560',
#     'recommendations': 3,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813069',
#     'isAnonymous': False},
#    {'commentID': 109814044,
#     'status': 'approved',
#     'commentSequence': 109814044,
#     'userID': 8148854,
#     'userDisplayName': 'Federalist',
#     'userLocation': 'California',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'As with Nazi ideology some violent mass delusions must simply be suppressed and stamped out, using force when required. The solution is to outlaw spreading the  false conspiracy theory as holocaust denial is outlawed in Germany.',
#     'createDate': '1603752314',
#     'updateDate': '1603785068',
#     'approveDate': '1603767560',
#     'recommendations': 5,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814044',
#     'isAnonymous': False},
#    {'commentID': 109812751,
#     'status': 'approved',
#     'commentSequence': 109812751,
#     'userID': 76915842,
#     'userDisplayName': 'Sean',
#     'userLocation': 'Westlake, OH',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Is this another sign of how stupid the American public has become?  Why are most stupid conspiracy theories always born on the right?',
#     'createDate': '1603746105',
#     'updateDate': '1603927588',
#     'approveDate': '1603767559',
#     'recommendations': 11,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109812751',
#     'isAnonymous': False},
#    {'commentID': 109812918,
#     'status': 'approved',
#     'commentSequence': 109812918,
#     'userID': 285150,
#     'userDisplayName': 'John',
#     'userLocation': 'New York',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Hunt Q down and Lock Him Up!',
#     'createDate': '1603746900',
#     'updateDate': '1603842493',
#     'approveDate': '1603767559',
#     'recommendations': 3,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109812918',
#     'isAnonymous': False},
#    {'commentID': 109813849,
#     'status': 'approved',
#     'commentSequence': 109813849,
#     'userID': 18156636,
#     'userDisplayName': 'vishmael',
#     'userLocation': 'madison, wi',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Missing here is why the seventeen of so US investigative agencies and/or an assortment of online hacker-tracker geniuses have not already sourced and outed principle QAnon activists with a view toward suppression or eradication of the malignant mental virus?\n\nPerhaps QAnon serves some purpose of higher-pay-grade conspirators such that the rumor mills are allowed - enabled, encouraged, subsidized - to keep spewing forth this psychic filth to the amusement and advantage of those controlling the levers of psycho-political power…',
#     'createDate': '1603751146',
#     'updateDate': '1603780030',
#     'approveDate': '1603767559',
#     'recommendations': 0,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813849',
#     'isAnonymous': False},
#    {'commentID': 109815311,
#     'status': 'approved',
#     'commentSequence': 109815311,
#     'userID': 84313941,
#     'userDisplayName': 'Jaegerle',
#     'userLocation': 'Heidelberg, Germany',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'QAnon\'s narrative of Deep State and New World Order is just a refreshed clone of an early antisemitic propaganda lore called "The Protocols of the Elder from Zion" created by the Ochrana, the secret service of the Russian czar Nikolaus II. at the dawn of the 20th century, which was originally intended to link jewish intellectuals with freemasonry. The nazis, especially their main hoax generator Julius Streicher with his arch-antisemite magazine "Der Stürmer" (comparable to today\'s Breitbart News), later added the age-old medieval story of  a jewish conspiracy to kidnap christian babies, ritually sacrifice them and drink their fresh blood in order to achieve longevity (there you go with Hillary\'s pizza parlor). \nThese \'protocols\' were first published in 1903, and their main purpose was to discredit jews and freemasons who the czar believed to be his opponents (a few years later the Bolshevists overthrew his regime and murdered his family).\nThey pointed out that there was an international financial elite which tries to dominate the whole world (as a first concept of globalization).\n\nSo you may easily see that this is actually old stuff warmed up in our present days. Nothing new, but scary enough when  believed by thugs who are armed to their teeth and feel deep inside that they are losers in history.',
#     'createDate': '1603759702',
#     'updateDate': '1603925508',
#     'approveDate': '1603767559',
#     'recommendations': 11,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109815311',
#     'isAnonymous': False},
#    {'commentID': 109813715,
#     'status': 'approved',
#     'commentSequence': 109813715,
#     'userID': 72750210,
#     'userDisplayName': 'JVM',
#     'userLocation': 'Binghamton, NY',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'I think it might be coded cover for anti-semetic, white power, sexist, homophobes united. Accepted deniability in absurdity. Cannibalism is code for blacks, pedophiles for gays, elites for Jews, liberals for feminists. A few followers take it literally at face value, but most probably share a tacit  understanding.',
#     'createDate': '1603750476',
#     'updateDate': '1603821348',
#     'approveDate': '1603767558',
#     'recommendations': 3,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813715',
#     'isAnonymous': False},
#    {'commentID': 109813106,
#     'status': 'approved',
#     'commentSequence': 109813106,
#     'userID': 58923635,
#     'userDisplayName': 'Billy',
#     'userLocation': 'The woods are lovely, dark and deep.',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/uncropped-499061f9f2fb25678489b547b35a501e2e2a82a5368148d7514800a0ec754c28.jpg',
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Like religions Q-anon will fragment in to W-X-Y & Z-anons.\n\nThere are plenty of morons to go around.',
#     'createDate': '1603747665',
#     'updateDate': '1603842521',
#     'approveDate': '1603767557',
#     'recommendations': 5,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813106',
#     'isAnonymous': False},
#    {'commentID': 109813357,
#     'status': 'approved',
#     'commentSequence': 109813357,
#     'userID': 81766355,
#     'userDisplayName': 'RjW',
#     'userLocation': 'Rolling Prairie',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'This is as dangerous as Naziism. I fully point the finger at Putin as he well knows exactly the most effective way to snuff the enlightenment flame we’ve miraculously kept alight these two and a half centuries.  With truth made either relative or inscrutable by information bubbles, we have begun to slip down the slope.  \nWinter is coming...',
#     'createDate': '1603748765',
#     'updateDate': '1603816394',
#     'approveDate': '1603767557',
#     'recommendations': 4,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813357',
#     'isAnonymous': False},
#    {'commentID': 109814873,
#     'status': 'approved',
#     'commentSequence': 109814873,
#     'userID': 85059034,
#     'userDisplayName': 'gtovey',
#     'userLocation': 'Mississippi',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Do the same thing about Q you do with Easter bunny and Bugs Bunny, laugh. After the election they will be harder to find, with their super-hero in prison.',
#     'createDate': '1603756816',
#     'updateDate': '1603816420',
#     'approveDate': '1603767557',
#     'recommendations': 4,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814873',
#     'isAnonymous': False},
#    {'commentID': 109813575,
#     'status': 'approved',
#     'commentSequence': 109813575,
#     'userID': 63938366,
#     'userDisplayName': 'Futbolistaviva',
#     'userLocation': 'SF Bay Area',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Condemn them and it.\nRidicule them and it.\nShame them and it.\nThen ignore them and it.\n\nWhen all is said and done, it will probably turn out to be a Russian propaganda stunt to gin up the idiotic cultists to assist the juvenile delinquent in the White House',
#     'createDate': '1603749814',
#     'updateDate': '1603821400',
#     'approveDate': '1603766989',
#     'recommendations': 7,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813575',
#     'isAnonymous': False},
#    {'commentID': 109813487,
#     'status': 'approved',
#     'commentSequence': 109813487,
#     'userID': 20802716,
#     'userDisplayName': 'Carl Zichella',
#     'userLocation': 'Davis, CA',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Sorry, but anyone who believes in Q is by definition stupid. Really stupid.',
#     'createDate': '1603749400',
#     'updateDate': '1603838860',
#     'approveDate': '1603766908',
#     'recommendations': 15,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813487',
#     'isAnonymous': False},
#    {'commentID': 109813420,
#     'status': 'approved',
#     'commentSequence': 109813420,
#     'userID': 63842161,
#     'userDisplayName': 'antiturd',
#     'userLocation': 'Massachusetts',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "These are stupid stupid times.  I'm not laughing, these idiots can do real damage, can be played by less than brilliant power grabbers.  What do we do about Q?  What do we do about the significant number of Americans who have near zero critical thinking skills?  Take away their idiot drug (phones)?",
#     'createDate': '1603749061',
#     'updateDate': '1603780138',
#     'approveDate': '1603766900',
#     'recommendations': 4,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813420',
#     'isAnonymous': False},
#    {'commentID': 109815096,
#     'status': 'approved',
#     'commentSequence': 109815096,
#     'userID': 99753816,
#     'userDisplayName': 'Jonathan',
#     'userLocation': 'USA',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "What do we do about Q?  We treat them as terrorists and subversives, because that's what they are.  \n     \nQ crazies are more dangerous than most terrorists, though, because their irrationality makes their actions unpredictable.  There's nothing more dangerous than a crazy with a gun.",
#     'createDate': '1603758203',
#     'updateDate': '1603819569',
#     'approveDate': '1603766747',
#     'recommendations': 7,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109815096',
#     'isAnonymous': False},
#    {'commentID': 109813955,
#     'status': 'approved',
#     'commentSequence': 109813955,
#     'userID': 155070,
#     'userDisplayName': 'Larry Raffalovich',
#     'userLocation': 'Slingerlands, NY',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': '"So what can you do? Is this the end?',
#     'createDate': '1603751737',
#     'updateDate': '1603770226',
#     'approveDate': '1603766746',
#     'recommendations': 1,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813955',
#     'isAnonymous': False},
#    {'commentID': 109814698,
#     'status': 'approved',
#     'commentSequence': 109814698,
#     'userID': 63452094,
#     'userDisplayName': 'Laurel McGuire',
#     'userLocation': 'Boise I’d',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'The ones well down the rabbit hole are hard to reach. To stop the curious from following it’s necessary to make fun of it and state clearly the outlandish parts otherwise they cont8nue thinking it’s all normal. Don’t just listen to their tales of save the children ask th3m if they really believe in cannibal pedophiles. Make them confront how bizarre it is. Don’t give it legitimacy.',
#     'createDate': '1603755807',
#     'updateDate': '1603909768',
#     'approveDate': '1603766746',
#     'recommendations': 5,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814698',
#     'isAnonymous': False},
#    {'commentID': 109813086,
#     'status': 'approved',
#     'commentSequence': 109813086,
#     'userID': 65867845,
#     'userDisplayName': 'Chris R',
#     'userLocation': 'Dallas',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'I give up. I’ve lost a life time best friend over this nonsense. He was best man at my wedding and vice versa. We can’t even discuss anything without him raising Q theories. I try to change the subject but things keep heading into the rabbit hole. I give up.',
#     'createDate': '1603747582',
#     'updateDate': '1603842547',
#     'approveDate': '1603766745',
#     'recommendations': 6,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109813086',
#     'isAnonymous': False},
#    {'commentID': 109814620,
#     'status': 'approved',
#     'commentSequence': 109814620,
#     'userID': 10360498,
#     'userDisplayName': 'tomB',
#     'userLocation': 'phila',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "Don't know what to do about cultists, but everyone else should be aware that Q is essentially a modernized version of the Protocols of the Elders of Zion, a conspiracy theory that swept the world 120 years ago and led to pogroms, world wars, European fascism and the Holocaust. The danger of Q, the consequences if it takes hold, cannot be overestimated.",
#     'createDate': '1603755365',
#     'updateDate': '1603909789',
#     'approveDate': '1603766743',
#     'recommendations': 8,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109814620',
#     'isAnonymous': False},
#    {'commentID': 109815061,
#     'status': 'approved',
#     'commentSequence': 109815061,
#     'userID': 56767034,
#     'userDisplayName': 'Paul',
#     'userLocation': 'Phoenix, AZ',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'What can we do about it?\n\nHow about sensationalist oriented cable networks like MSNBC stop promoting it by running stories that start out this way:\n\nBREAKING NEWS!\n\n"Steve Bannon fanning the flames of another conspiracy theory."\n\nI can find about 4 different ways this single intro to the story is journalistic malpractice.',
#     'createDate': '1603757979',
#     'updateDate': '1603785238',
#     'approveDate': '1603766743',
#     'recommendations': 2,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '109815061',
#     'isAnonymous': False}],
#   'depthLimit': 2,
#   'filter': '',
#   'page': 1,
#   'replyLimit': 3,
#   'sort': '',
#   'totalCommentsFound': 749,
#   'totalCommentsReturned': 25,
#   'totalEditorsSelectionFound': 14,
#   'totalEditorsSelectionReturned': 0,
#   'totalParentCommentsFound': 474,
#   'totalParentCommentsReturned': 25,
#   'totalRecommendationsFound': 489,
#   'totalRecommendationsReturned': 23,
#   'totalReplyCommentsFound': 275,
#   'totalReplyCommentsReturned': 0,
#   'totalReporterReplyCommentsFound': 0,
#   'totalReporterReplyCommentsReturned': 0,
#   'userData': {'userID': 0,
#    'login': None,
#    'email': '',
#    'displayName': '',
#    'url': '',
#    'title': '',
#    'location': '',
#    'times_people': 0,
#    'sharing': 0,
#    'labels': []}},
#  'errorDetails': ''}

# %% [markdown]
# ## Get the comment body from data

# %%
comment_data =  data['results']['comments']

#put comment body in a list
comments_body = []
for comment in comment_data:
    comments_body.append(comment['commentBody'])

print (comments_body)
# Out:
# ["Speaking in codes happens in countries losing grip on their ability to speak freely. People living in fear.\n\nBeing from NYC it was urban legend that all pizza parlors were owned and run by the mafia. When a character like Alex Jones says a child sex ring is being run out of a pizzeria, wht was he implying? Then the Epstein/Maxwell story broke. They did it all on their own? Were they the Lizard People From the Fifth Dimension Alex Jones connected to the pizzeria? \n\nThere are busts every year in Houston of pedophiles. Nearly every law enforcement organization is involved from the Houston police to the Dept of Homeland Security. It is described as a hub for sex trafficking. What exactly does that mean? The news tells us about the arrest but we are never the whole picture. How many hubs exist? Who is involved? Why do we have to go to alternate media to find remnants of the truth?\n\nInternational Pedophile rings don't  exist do they? And the rich would never do nothing so disgusting? You'd have to be a paranoid fool to believe such things. Prince Andrew and Bill Clinton? Only haters would say anything bad about them.\n\nThe nytimes usually doesn't print post  like this. It' was fun trying though.", 'Noam Chomsky? That one photo colors your entire report as sloppy.', 'Maybe "Q" is actually a Russian disinformation campaign.', "I guess the German's fell for the line that Jews were eating babies, and the economic metrics are similar, a lot of desperate poor people and a few rich people controlling all the money. So Donald gets it into his head from one of his sociopathic advisors that he should stick with QAnon. It has legs! \n\nI don't think so. We're not 1933 Germans. We're a bunch of diverse people who will withstand the defilement of our country. We will accept our responsibilities to the world that we have not always been kind to. We need to grow up.", 'QAnon, Trump, McConnell, and Amy Coney Barrett. Let’s see hear...\n\nAn ancient alien race’s artifact is found by Fred Trump when fighting child brain-sucking Democrat communists in 1953. His son used the very powerful talisman to summon Amy Coney Barrett from McConnell’s horse farm in Kentucky to become the first High Priestess of the Supreme Court.\n\nIf you say it over and over, it almost makes sense. I’ll entertain streaming offers.\n\nI’m humbled by the Old Testament prophecy of comedian Ron White... You just can’t fix stupid!', "Go for the jocular (not jugular) vein. Not sure who to attribute this to (Barney Frank?)\n\nOr as Jefferson put it:\n  ridicule is the only weapon which can be used against unintelligible propositions. ideas must be distinct before reason can act upon them; ...\n\nI just  double down on any QAnon-type  stupidity that happens in my presence. Eg Rush's idiotic Obama is a Islamo-fascist.", "I'm no Q supporter but what a waste of 10 minutes. Psycho gobbledygook. Never delves into what the Qanons say re: the pedo cult... it's just absurd... so, nothing there.  Pathetic!", 'As with Nazi ideology some violent mass delusions must simply be suppressed and stamped out, using force when required. The solution is to outlaw spreading the  false conspiracy theory as holocaust denial is outlawed in Germany.', 'Is this another sign of how stupid the American public has become?  Why are most stupid conspiracy theories always born on the right?', 'Hunt Q down and Lock Him Up!', 'Missing here is why the seventeen of so US investigative agencies and/or an assortment of online hacker-tracker geniuses have not already sourced and outed principle QAnon activists with a view toward suppression or eradication of the malignant mental virus?\n\nPerhaps QAnon serves some purpose of higher-pay-grade conspirators such that the rumor mills are allowed - enabled, encouraged, subsidized - to keep spewing forth this psychic filth to the amusement and advantage of those controlling the levers of psycho-political power…', 'QAnon\'s narrative of Deep State and New World Order is  ...

# %% [markdown]
# ## Calling Perspective API

# %%
perspective_apikey = "***************"

# url for perspective api
url = ('https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze' +
    '?key=' + perspective_apikey)

# %% [markdown]
# ## Test the comment for TOXICITY score

# %%
scores = []

for comment in comments_body:
    data_dict = {
    'comment': {'text': comment},
    'languages': ['en'],
    'requestedAttributes': {'TOXICITY': {}}
    }

    # append every score value into a list
    response = requests.post(url=url, data=json.dumps(data_dict))
    response_dict = json.loads(response.content)
    scores.append(response_dict)

print(scores) #a list of response from perspective api
# Out:
# [{'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 1207, 'score': {'value': 0.5803554, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.5803554, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 65, 'score': {'value': 0.29070637, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.29070637, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 56, 'score': {'value': 0.100408874, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.100408874, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 534, 'score': {'value': 0.53490317, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.53490317, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 531, 'score': {'value': 0.8060606, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.8060606, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 382, 'score': {'value': 0.8785311, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.8785311, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 180, 'score': {'value': 0.8074953, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.8074953, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 228, 'score': {'value': 0.2827775, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.2827775, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 133, 'score': {'value': 0.8606264, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.8606264, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 28, 'score': {'value': 0.4907518, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.4907518, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 531, 'score': {'value': 0.44766575, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.44766575, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 1319, 'score': {'value': 0.5077852, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.5077852, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 315, 'score': {'value': 0.76868147, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.76868147, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 100, 'score': {'value': 0.8606264, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.8606264, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 342, 'score': {'value': 0.37126365, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.37126365, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 154, 'score': {'value': 0.15561453, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.15561453, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}, {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 257, 'score ...

# %% [markdown]
# ## Loop thru list to get the summaryScore value for each comment

# %%
#parse out the score value from scores list
score_values = []
for score in scores:
    score_values.append(score['attributeScores']['TOXICITY']['summaryScore']['value'])

print(score_values)
# Out:
# [0.5803554, 0.29070637, 0.100408874, 0.53490317, 0.8060606, 0.8785311, 0.8074953, 0.2827775, 0.8606264, 0.4907518, 0.44766575, 0.5077852, 0.76868147, 0.8606264, 0.37126365, 0.15561453, 0.8530424, 0.93232936, 0.9403218, 0.5722081, 0.062145516, 0.44082078, 0.4289077, 0.17141418, 0.096745454]

# %% [markdown]
# ## Turn comments and score value into a dict

# %%
#turn comments list and score_values list to a dict
#This function pairs the list element with other list element at corresponding index in form of key-value pairs.
comment_val_dict = dict(zip(comments_body, score_values)) #dict(zip(keys, values))

print(type(comment_val_dict))
comment_val_dict
# Out:
# <class 'dict'>
# {"Speaking in codes happens in countries losing grip on their ability to speak freely. People living in fear.\n\nBeing from NYC it was urban legend that all pizza parlors were owned and run by the mafia. When a character like Alex Jones says a child sex ring is being run out of a pizzeria, wht was he implying? Then the Epstein/Maxwell story broke. They did it all on their own? Were they the Lizard People From the Fifth Dimension Alex Jones connected to the pizzeria? \n\nThere are busts every year in Houston of pedophiles. Nearly every law enforcement organization is involved from the Houston police to the Dept of Homeland Security. It is described as a hub for sex trafficking. What exactly does that mean? The news tells us about the arrest but we are never the whole picture. How many hubs exist? Who is involved? Why do we have to go to alternate media to find remnants of the truth?\n\nInternational Pedophile rings don't  exist do they? And the rich would never do nothing so disgusting? You'd have to be a paranoid fool to believe such things. Prince Andrew and Bill Clinton? Only haters would say anything bad about them.\n\nThe nytimes usually doesn't print post  like this. It' was fun trying though.": 0.5803554,
#  'Noam Chomsky? That one photo colors your entire report as sloppy.': 0.29070637,
#  'Maybe "Q" is actually a Russian disinformation campaign.': 0.100408874,
#  "I guess the German's fell for the line that Jews were eating babies, and the economic metrics are similar, a lot of desperate poor people and a few rich people controlling all the money. So Donald gets it into his head from one of his sociopathic advisors that he should stick with QAnon. It has legs! \n\nI don't think so. We're not 1933 Germans. We're a bunch of diverse people who will withstand the defilement of our country. We will accept our responsibilities to the world that we have not always been kind to. We need to grow up.": 0.53490317,
#  'QAnon, Trump, McConnell, and Amy Coney Barrett. Let’s see hear...\n\nAn ancient alien race’s artifact is found by Fred Trump when fighting child brain-sucking Democrat communists in 1953. His son used the very powerful talisman to summon Amy Coney Barrett from McConnell’s horse farm in Kentucky to become the first High Priestess of the Supreme Court.\n\nIf you say it over and over, it almost makes sense. I’ll entertain streaming offers.\n\nI’m humbled by the Old Testament prophecy of comedian Ron White... You just can’t fix stupid!': 0.8060606,
#  "Go for the jocular (not jugular) vein. Not sure who to attribute this to (Barney Frank?)\n\nOr as Jefferson put it:\n  ridicule is the only weapon which can be used against unintelligible propositions. ideas must be distinct before reason can act upon them; ...\n\nI just  double down on any QAnon-type  stupidity that happens in my presence. Eg Rush's idiotic Obama is a Islamo-fascist.": 0.8785311,
#  "I'm no Q supporter but what a waste of 10 minutes. Psycho gobbledygook. Never delves into what the Qanons say re: the pedo cult... it's just absurd... so, nothing there.  Pathetic!": 0.8074953,
#  'As with Nazi ideology some violent mass delusions must simply be suppressed and stamped out, using force when required. The solution is to outlaw spreading the  false conspiracy theory as holocaust denial is outlawed in Germany.': 0.2827775,
#  'Is this another sign of how stupid the American public has become?  Why are most stupid conspiracy theories always born on the right?': 0.8606264,
#  'Hunt Q down and Lock Him Up!': 0.4907518,
#  'Missing here is why the seventeen of so US investigative agencies and/or an assortment of online hacker-tracker geniuses have not already sourced and outed principle QAnon activists with a view toward suppression or eradication of the malignant mental virus?\n\nPerhaps QAnon serves some purpose of higher-pay-grade conspirators such that the rumor mills are allowed - enabled, encouraged, subsidized - to keep spewing forth this psychic filth to the amusement and advantage of those controlling the levers of psycho-political power…': 0.44766575,
#  'QAnon\'s narrative of Deep State and New World Order is just a refreshed clone of an early antisemitic propaganda lore called "The Protocols of the Elder from Zion" created by the Ochrana, the secret service of the Russian czar Nikolaus II. at the dawn of the 20th century, which was originally intended to link jewish intellectuals with freemasonry. The nazis, especially their main hoax generator Julius Streicher with his arch-antisemite magazine "Der Stürmer" (comparable to today\'s Breitbart News), later added the age-old medieval story of  a jewish conspiracy to kidnap christian babies, ritually sacrifice them and drink their fresh blood in order to achieve longevity (there you go with Hillary\'s pizza parlor). \nThese \'protocols\' were first published in 1903, and their main purpose was to discredit jews and freemasons who the czar believed to be his opponents (a few years later the Bolshevists overthrew his regime and murdered his family).\nThey pointed out that there was an international financial elite which tries to dominate the whole world (as a first concept of globalization).\n\nSo you may easily see that this is actually old stuff warmed up in our present days. Nothing new, but scary enough when  believed by thugs who are armed to their teeth and feel deep inside that they are losers in history.': 0.5077852,
#  'I think it might be coded cover for anti-semetic, white power, sexist, homophobes united. Accepted deniability in absurdity. Cannibalism is code for blacks, pedophiles for gays, elites for Jews, liberals for feminists. A few followers take it literally at face value, but most probably share a tacit  understanding.': 0.76868147,
#  'Like religions Q-anon will fragment in to W-X-Y & Z-anons.\n\nThere are plenty of morons to go around.': 0.8606264,
#  'This is as dangerous as Naziism. I fully point the finger at Putin as he well knows exactly the most effective way to snuff the enlightenment flame we’ve miraculously kept alight these two and a half centuries.  With truth made either relative or inscrutable by information bubbles, we have begun to slip down the slope.  \nWinter is coming...': 0.37126365,
#  'Do the same thing about Q you do with Easter bunny and Bugs Bunny, laugh. After the election they will be harder to find, with their super-hero in prison.': 0.15561453,
#  'Condemn them and it.\nRidicule them and it.\nShame them and it.\nThen ignore them and it.\n\nWhen all is said and done, it will probably turn out to be a Russian propaganda stunt to gin up the idiotic cultists to assist the juvenile delinquent in the White House': 0.8530424,
#  'Sorry, but anyone who believes in Q is by definition stupid. Really stupid.': 0.93232936,
#  "These are stupid stupid times.  I'm not laughing, these idiots can do real damage, can be played by less than brilliant power grabbers.  What do we do about Q?  What do we do about the significant number of Americans who have near zero critical thinking skills?  Take away their idiot drug (phones)?": 0.9403218,
#  "What do we do about Q?  We treat them as terrorists and subversives, because that's what they are.  \n     \nQ crazies are more dangerous than most terrorists, though, because their irrationality makes their actions unpredictable.  There's nothing more dangerous than a crazy with a gun.": 0.5722081,
#  '"So what can you do? Is this the end?': 0.062145516,
#  'The ones well down the rabbit hole are hard to reach. To stop the curious from following it’s necessary to make fun of it and state clearly the outlandish parts otherwise they cont8nue thinking it’s all normal. Don’t just listen to their tales of save the children ask th3m if they really believe in cannibal pedophiles. Make them confront how bizarre it is. Don’t give it legitimacy.': 0.44082078,
#  'I give up. I’ve lost a life time best friend over this nonsense. He was best man at my wedding and vice versa. We can’t even discuss anything without him raising Q theories. I try to change the subject but things keep heading into the rabbit hole. I give up.': 0.4289077,
#  "Don't know what to do about cultists, but everyone else should be aware that Q is essentially a modernized version of the Protocols of the Elders of Zion, a conspiracy theory that swept the world 120 years ago and led to pogroms, world wars, European fascism and the Holocaust. The danger of Q, the consequences if it takes hold, cannot be overestimated.": 0.17141418,
#  'What can we do about it?\n\nHow about sensationalist oriented cable networks like MSNBC stop promoting it by running stories that start out this way:\n\nBREAKING NEWS!\n\n"Steve Bannon fanning the flames of another conspiracy theory."\n\nI can find about 4 different ways this single intro to the story is journalistic malpractice.': 0.096745454}

# %% [markdown]
# ## Turn the dict into a data frame

# %%
# make dataframe from a dict
df = pd.DataFrame(list(comment_val_dict.items()),columns = ['Comments','Score'])

pd.options.display.max_colwidth = 1000
# df

# %% [markdown]
# ## Add a new column based on conditions¶
#
# Tutorial [link](https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/)

# %%
# create a list of our conditions
conditions = [
    (df['Score'] < 0.1),
    (df['Score'] >= 0.1) & (df['Score'] <= 0.5),
    (df['Score'] > 0.5)
    ]

# create a list of the values we want to assign for each condition
values = ['low', 'medium', 'high']

# create a new column and use np.select to assign values to it using our lists as arguments
df['Priority'] = np.select(conditions, values)

# sorting from high to low
df.sort_values(by='Score', ascending=False, inplace=True)
#reset index
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Comments  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               These are stupid stupid times.  I'm not laughing, these idiots can do real damage, can be played by less than brilliant power grabbers.  What do we do about Q?  What do we do about the significant number of Americans who have near zero critical thinking skills?  Take away their idiot drug (phones)?
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Sorry, but anyone who believes in Q is by definition stupid. Really stupid.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Go for the jocular (not jugular) vein. Not sure who to attribute this to (Barney Frank?)\n\nOr as Jefferson put it:\n  ridicule is the only weapon which can be used against unintelligible propositions. ideas must be distinct before reason can act upon them; ...\n\nI just  double down on any QAnon-type  stupidity that happens in my presence. Eg Rush's idiotic Obama is a Islamo-fascist.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Like religions Q-anon will fragment in to W-X-Y & Z-anons.\n\nThere are plenty of morons to go around.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Is this another sign of how stupid the American public has become?  Why are most stupid conspiracy theories always born on the right?
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Condemn them and it.\nRidicule them and it.\nShame them and it.\nThen ignore them and it.\n\nWhen all is said and done, it will probably turn out to be a Russian propaganda stunt to gin up the idiotic cultists to assist the juvenile delinquent in the White House
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I'm no Q supporter but what a waste of 10 minutes. Psycho gobbledygook. Never delves into what the Qanons say re: the pedo cult... it's just absurd... so, nothing there.  Pathetic!
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 QAnon, Trump, McConnell, and Amy Coney Barrett. Let’s see hear...\n\nAn ancient alien race’s artifact is found by Fred Trump when fighting child brain-sucking Democrat communists in 1953. His son used the very powerful talisman to summon Amy Coney Barrett from McConnell’s horse farm in Kentucky to become the first High Priestess of the Supreme Court.\n\nIf you say it over and over, it almost makes sense. I’ll entertain streaming offers.\n\nI’m humbled by the Old Testament prophecy of comedian Ron White... You just can’t fix stupid!
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I think it might be coded cover for anti-semetic, white power, sexist, homophobes united. Accepted deniability in absurdity. Cannibalism is code for blacks, pedophiles for gays, elites for Jews, liberals for feminists. A few followers take it literally at face value, but most probably share a tacit  understanding.
# 9   Speaking in codes happens in countries losing grip on their ability to speak freely. People living in fear.\n\nBeing from NYC it was urban legend that all pizza parlors were owned and run by the mafia. When a character like Alex Jones says a child sex ring is being run out of a pizzeria, wht was he implying? Then the Epstein/Maxwell story broke. They did it all on their own? Were they the Lizard People From the Fifth Dimension Alex Jones connected to the pizzeria? \n\nThere are busts every year in Houston of pedophiles. Nearly every law enforcement organization is involved from the Houston police to the Dept of Homeland Security. It is described as a hub for sex trafficking. What exactly does that mean? The news tells us about the arrest but we are never the whole picture. How many hubs exist? Who is involved? Why do we have to go to alternate media to find remnants of the truth?\n\nInternational Pedophile rings don't  exist do they? And the rich would never do nothing so disgustin...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          What do we do about Q?  We treat them as terrorists and subversives, because that's what they are.  \n     \nQ crazies are more dangerous than most terrorists, though, because their irrationality makes their actions unpredictable.  There's nothing more dangerous than a crazy with a gun.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I guess the German's fell for the line that Jews were eating babies, and the economic metrics are similar, a lot of desperate poor people and a few rich people controlling all the money. So Donald gets it into his head from one of his sociopathic advisors that he should stick with QAnon. It has legs! \n\nI don't think so. We're not 1933 Germans. We're a bunch of diverse people who will withstand the defilement of our country. We will accept our responsibilities to the world that we have not always been kind to. We need to grow up.
# 12  QAnon's narrative of Deep State and New World Order is just a refreshed clone of an early antisemitic propaganda lore called "The Protocols of the Elder from Zion" created by the Ochrana, the secret service of the Russian czar Nikolaus II. at the dawn of the 20th century, which was originally intended to link jewish intellectuals with freemasonry. The nazis, especially their main hoax generator Julius Streicher with his arch-antisemite magazine "Der Stürmer" (comparable to today's Breitbart News), later added the age-old medieval story of  a jewish conspiracy to kidnap christian babies, ritually sacrifice them and drink their fresh blood in order to achieve longevity (there you go with Hillary's pizza parlor). \nThese 'protocols' were first published in 1903, and their main purpose was to discredit jews and freemasons who the czar believed to be his opponents (a few years later the Bolshevists overthrew his regime and murdered his family).\nThey pointed out that there was an intern...
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Hunt Q down and Lock Him Up!
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Missing here is why the seventeen of so US investigative agencies and/or an assortment of online hacker-tracker geniuses have not already sourced and outed principle QAnon activists with a view toward suppression or eradication of the malignant mental virus?\n\nPerhaps QAnon serves some purpose of higher-pay-grade conspirators such that the rumor mills are allowed - enabled, encouraged, subsidized - to keep spewing forth this psychic filth to the amusement and advantage of those controlling the levers of psycho-political power…
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         The ones well down the rabbit hole are hard to reach. To stop the curious from following it’s necessary to make fun of it and state clearly the outlandish parts otherwise they cont8nue thinking it’s all normal. Don’t just listen to their tales of save the children ask th3m if they really believe in cannibal pedophiles. Make them confront how bizarre it is. Don’t give it legitimacy.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I give up. I’ve lost a life time best friend over this nonsense. He was best man at my wedding and vice versa. We can’t even discuss anything without him raising Q theories. I try to change the subject but things keep heading into the rabbit hole. I give up.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  This is as dangerous as Naziism. I fully point the finger at Putin as he well knows exactly the most effective way to snuff the enlightenment flame we’ve miraculously kept alight these two and a half centuries.  With truth made either relative or inscrutable by information bubbles, we have begun to slip down the slope.  \nWinter is coming...
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Noam Chomsky? That one photo colors your entire report as sloppy.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     As with Nazi ideology some violent mass delusions must simply be suppressed and stamped out, using force when required. The solution is to outlaw spreading the  false conspiracy theory as holocaust denial is outlawed in Germany.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Don't know what to do about cultists, but everyone else should be aware that Q is essentially a modernized version of the Protocols of the Elders of Zion, a conspiracy theory that swept the world 120 years ago and led to pogroms, world wars, European fascism and the Holocaust. The danger of Q, the consequences if it takes hold, cannot be overestimated.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Do the same thing about Q you do with Easter bunny and Bugs Bunny, laugh. After the election they will be harder to find, with their super-hero in prison.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Maybe "Q" is actually a Russian disinformation campaign.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              What can we do about it?\n\nHow about sensationalist oriented cable networks like MSNBC stop promoting it by running stories that start out this way:\n\nBREAKING NEWS!\n\n"Steve Bannon fanning the flames of another conspiracy theory."\n\nI can find about 4 different ways this single intro to the story is journalistic malpractice.
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    "So what can you do? Is this the end?
#
#        Score Priority
# 0   0.940322     high
# 1   0.932329     high
# 2   0.878531     high
# 3   0.860626     high
# 4   0.860626     high
# 5   0.853042     high
# 6   0.807495     high
# 7   0.806061     high
# 8   0.768681     high
# 9   0.580355     high
# 10  0.572208     high
# 11  0.534903     high
# 12  0.507785     high
# 13  0.490752   medium
# 14  0.447666   medium
# 15  0.440821   medium
# 16  0.428908   medium
# 17  0.371264   medium
# 18  0.290706   medium
# 19  0.282778   medium
# 20  0.171414   medium
# 21  0.155615   medium
# 22  0.100409   medium
# 23  0.096745      low
# 24  0.062146      low

# %% [markdown]
# ## Count number of each ranks

# %%
df['Priority'].value_counts()
# Out:
# high      13
# medium    10
# low        2
# Name: Priority, dtype: int64

# %% [markdown]
# ## Save df to a csv file

# %%
# df.to_csv('nytimes-comments-ranking.csv')
