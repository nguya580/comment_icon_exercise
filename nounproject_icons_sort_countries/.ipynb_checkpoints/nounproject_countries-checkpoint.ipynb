# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

import json

import requests
from requests_oauthlib import OAuth1

# %% [markdown]
# # Prep API and request
#
# Call for **food** icons and show 50 results limit

# %%
auth = OAuth1("Insert-Key", "Insert-Secret")

#Call for food icons and show 50 results limit
endpoint = "http://api.thenounproject.com/icons/food?&limit=50"

response = requests.get(endpoint, auth=auth)

data = response.content

# %% [markdown]
# # Get uploaders data

# %%
# Load the JSON to a Python list & dump it back out as formatted JSON
data = json.loads(data)
data

uploaders = []

for icon in data['icons']:
    uploaders.append(icon['uploader'])

uploaders
# Out:
# [{'location': 'New York City, New York, US',
#   'name': 'OCHA Visual',
#   'permalink': '/ochavisual',
#   'username': 'ochavisual'},
#  {'location': 'Moscow, RU',
#   'name': 'Anuar Zhumaev',
#   'permalink': '/yxorama',
#   'username': 'yxorama'},
#  {'location': 'Moscow, RU',
#   'name': 'Anuar Zhumaev',
#   'permalink': '/yxorama',
#   'username': 'yxorama'},
#  {'location': 'Los Angeles, CA, US',
#   'name': '✦ Shmidt Sergey ✦',
#   'permalink': '/monstercritic',
#   'username': 'monstercritic'},
#  {'location': 'lausanne, Suisse, CH',
#   'name': 'stephanie wauters',
#   'permalink': '/Stephanie Wauters',
#   'username': 'Stephanie Wauters'},
#  {'location': 'Berlin, Berlin, DE',
#   'name': 'Sebastian Langer',
#   'permalink': '/sebastian.langer.330',
#   'username': 'sebastian.langer.330'},
#  {'location': 'Paris, France, FR',
#   'name': 'Rémy Médard',
#   'permalink': '/catalarem',
#   'username': 'catalarem'},
#  {'location': 'Los Angeles, California, US',
#   'name': 'Matt Brooks',
#   'permalink': '/Mattebrooks',
#   'username': 'Mattebrooks'},
#  {'location': '',
#   'name': 'Live Fish',
#   'permalink': '/bmomulon',
#   'username': 'bmomulon'},
#  {'location': 'US',
#   'name': 'Michael Loupos',
#   'permalink': '/mikeydoesit',
#   'username': 'mikeydoesit'},
#  {'location': '',
#   'name': 'Rob Lavender',
#   'permalink': '/roblav',
#   'username': 'roblav'},
#  {'location': 'Bangkok, TH',
#   'name': 'NATAPON CHANTABUTR',
#   'permalink': '/piq',
#   'username': 'piq'},
#  {'location': 'Edinburgh, GB',
#   'name': 'Claire Jones',
#   'permalink': '/hivernoir',
#   'username': 'hivernoir'},
#  {'location': 'BR',
#   'name': 'Manuela Ribas',
#   'permalink': '/manuribas',
#   'username': 'manuribas'},
#  {'location': 'Hemel Hempstead, Hertfordshire, GB',
#   'name': 'Slawek Jurczyk',
#   'permalink': '/slawekjurczyk',
#   'username': 'slawekjurczyk'},
#  {'location': 'Hemel Hempstead, Hertfordshire, GB',
#   'name': 'Slawek Jurczyk',
#   'permalink': '/slawekjurczyk',
#   'username': 'slawekjurczyk'},
#  {'location': 'Sydney, New South Wales, AU',
#   'name': 'Gosia Gasiorowski',
#   'permalink': '/goshahh',
#   'username': 'goshahh'},
#  {'location': 'Mumbai, Maharashtra, IN',
#   'name': 'Karthik M',
#   'permalink': '/imkarthik',
#   'username': 'imkarthik'},
#  {'location': 'Mobile, Alabama, US',
#   'name': 'Alma Hoffmann',
#   'permalink': '/almah',
#   'username': 'almah'},
#  {'location': '',
#   'name': 'Mister Pixel',
#   'permalink': '/MisterPixel',
#   'username': 'MisterPixel'},
#  {'location': '',
#   'name': 'Mister Pixel',
#   'permalink': '/MisterPixel',
#   'username': 'MisterPixel'},
#  {'location': '',
#   'name': 'Mister Pixel',
#   'permalink': '/MisterPixel',
#   'username': 'MisterPixel'},
#  {'location': 'İzmir, TR',
#   'name': 'Doub.co',
#   'permalink': '/doub',
#   'username': 'doub'},
#  {'location': 'Olympia, WA, Washington, US',
#   'name': 'Luis Prado',
#   'permalink': '/Luis',
#   'username': 'Luis'},
#  {'location': 'Edinburgh, GB',
#   'name': 'Claire Jones',
#   'permalink': '/hivernoir',
#   'username': 'hivernoir'},
#  {'location': 'Sofia, BG',
#   'name': 'Stefan Parnarov',
#   'permalink': '/sapi',
#   'username': 'sapi'},
#  {'location': 'Paris, France, FR',
#   'name': 'Milky - Digital innovation',
#   'permalink': '/Milky',
#   'username': 'Milky'},
#  {'location': 'Paris, France, FR',
#   'name': 'Milky - Digital innovation',
#   'permalink': '/Milky',
#   'username': 'Milky'},
#  {'location': 'Paris, France, FR',
#   'name': 'Milky - Digital innovation',
#   'permalink': '/Milky',
#   'username': 'Milky'},
#  {'location': 'Paris, France, FR',
#   'name': 'Milky - Digital innovation',
#   'permalink': '/Milky',
#   'username': 'Milky'},
#  {'location': 'Edinburgh, GB',
#   'name': 'Claire Jones',
#   'permalink': '/hivernoir',
#   'username': 'hivernoir'},
#  {'location': 'Edinburgh, GB',
#   'name': 'Claire Jones',
#   'permalink': '/hivernoir',
#   'username': 'hivernoir'},
#  {'location': 'Edinburgh, GB',
#   'name': 'Claire Jones',
#   'permalink': '/hivernoir',
#   'username': 'hivernoir'},
#  {'location': ' DF, México, MX',
#   'name': 'Rodolfo Alvarez',
#   'permalink': '/dg.rodolfoalvarez',
#   'username': 'dg.rodolfoalvarez'},
#  {'location': 'London, GB',
#   'name': 'iconsmind.com',
#   'permalink': '/imicons',
#   'username': 'imicons'},
#  {'location': 'London, GB',
#   'name': 'iconsmind.com',
#   'permalink': '/imicons',
#   'username': 'imicons'},
#  {'location': 'Bangalore, Karnataka, IN',
#   'name': 'Rohith M S',
#   'permalink': '/rohithdezinr',
#   'username': 'rohithdezinr'},
#  {'location': 'Madrid, ES',
#   'name': 'Ricardo Mena ',
#   'permalink': '/ricardo_mena',
#   'username': 'ricardo_mena'},
#  {'location': 'Lahore, Punjab, PK',
#   'name': 'Creative Stall',
#   'permalink': '/creativestall',
#   'username': 'creativestall'},
#  {'location': 'Tehran, Tehran, IR',
#   'name': 'Hadi Davodpour',
#   'permalink': '/hadivoice',
#   'username': 'hadivoice'},
#  {'location': 'Chennai, Tamilnadu, IN',
#   'name': 'Ramakrishna Venkatesan',
#   'permalink': '/RamakrishnaUX',
#   'username': 'RamakrishnaUX'},
#  {'location': 'Lahore, Punjab, PK',
#   'name': 'Creative Stall',
#   'permalink': '/creativestall',
#   'username': 'creativestall'},
#  {'location': 'Lahore, Punjab, PK',
#   'name': 'Creative Stall',
#   'permalink': '/creativestall',
#   'username': 'creativestall'},
#  {'location': 'Monterrey, Nuevo León, MX',
#   'name': 'Miguel C Balandrano',
#   'permalink': '/balandrano',
#   'username': 'balandrano'},
#  {'location': '',
#   'name': '23 icons',
#   'permalink': '/x09231986x',
#   'username': 'x09231986x'},
#  {'location': 'Lausanne, CH',
#   'name': 'Antistatique',
#   'permalink': '/antistatique',
#   'username': 'antistatique'},
#  {'location': 'cairo, EG',
#   'name': 'Peter Magdy',
#   'permalink': '/Mangawy',
#   'username': 'Mangawy'},
#  {'location': '',
#   'name': 'Gregor Cresnar',
#   'permalink': '/grega.cresnar',
#   'username': 'grega.cresnar'},
#  {'location': 'Vancouver (East Mount Pleasant), British Columbia, CA',
#   'name': 'Jamie Rothwell',
#   'permalink': '/jamiesonrothwell',
#   'username': 'jamiesonrothwell'},
#  {'location': 'san severo, IT',
#   'name': 'Maurizio Fusillo',
#   'permalink': '/fusillomaurizio',
#   'username': 'fusillomaurizio'}]

# %% [markdown]
# # Pandas the uploaders data

# %%
df = pd.DataFrame(uploaders)

pd.set_option('display.max_rows', 60)

df
# Out:
#                                              location  \
# 0                         New York City, New York, US
# 1                                          Moscow, RU
# 2                                          Moscow, RU
# 3                                 Los Angeles, CA, US
# 4                                lausanne, Suisse, CH
# 5                                  Berlin, Berlin, DE
# 6                                   Paris, France, FR
# 7                         Los Angeles, California, US
# 8
# 9                                                  US
# 10
# 11                                        Bangkok, TH
# 12                                      Edinburgh, GB
# 13                                                 BR
# 14                 Hemel Hempstead, Hertfordshire, GB
# 15                 Hemel Hempstead, Hertfordshire, GB
# 16                        Sydney, New South Wales, AU
# 17                            Mumbai, Maharashtra, IN
# 18                                Mobile, Alabama, US
# 19
# 20
# 21
# 22                                          İzmir, TR
# 23                        Olympia, WA, Washington, US
# 24                                      Edinburgh, GB
# 25                                          Sofia, BG
# 26                                  Paris, France, FR
# 27                                  Paris, France, FR
# 28                                  Paris, France, FR
# 29                                  Paris, France, FR
# 30                                      Edinburgh, GB
# 31                                      Edinburgh, GB
# 32                                      Edinburgh, GB
# 33                                     DF, México, MX
# 34                                         London, GB
# 35                                         London, GB
# 36                           Bangalore, Karnataka, IN
# 37                                         Madrid, ES
# 38                                 Lahore, Punjab, PK
# 39                                 Tehran, Tehran, IR
# 40                             Chennai, Tamilnadu, IN
# 41                                 Lahore, Punjab, PK
# 42                                 Lahore, Punjab, PK
# 43                          Monterrey, Nuevo León, MX
# 44
# 45                                       Lausanne, CH
# 46                                          cairo, EG
# 47
# 48  Vancouver (East Mount Pleasant), British Colum...
# 49                                     san severo, IT
#
#                           name              permalink              username
# 0                  OCHA Visual            /ochavisual            ochavisual
# 1                Anuar Zhumaev               /yxorama               yxorama
# 2                Anuar Zhumaev               /yxorama               yxorama
# 3            ✦ Shmidt Sergey ✦         /monstercritic         monstercritic
# 4            stephanie wauters     /Stephanie Wauters     Stephanie Wauters
# 5             Sebastian Langer  /sebastian.langer.330  sebastian.langer.330
# 6                  Rémy Médard             /catalarem             catalarem
# 7                  Matt Brooks           /Mattebrooks           Mattebrooks
# 8                    Live Fish              /bmomulon              bmomulon
# 9               Michael Loupos           /mikeydoesit           mikeydoesit
# 10                Rob Lavender                /roblav                roblav
# 11          NATAPON CHANTABUTR                   /piq                   piq
# 12                Claire Jones             /hivernoir             hivernoir
# 13               Manuela Ribas             /manuribas             manuribas
# 14              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 15              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 16           Gosia Gasiorowski               /goshahh               goshahh
# 17                   Karthik M             /imkarthik             imkarthik
# 18               Alma Hoffmann                 /almah                 almah
# 19                Mister Pixel           /MisterPixel           MisterPixel
# 20                Mister Pixel           /MisterPixel           MisterPixel
# 21                Mister Pixel           /MisterPixel           MisterPixel
# 22                     Doub.co                  /doub                  doub
# 23                  Luis Prado                  /Luis                  Luis
# 24                Claire Jones             /hivernoir             hivernoir
# 25             Stefan Parnarov                  /sapi                  sapi
# 26  Milky - Digital innovation                 /Milky                 Milky
# 27  Milky - Digital innovation                 /Milky                 Milky
# 28  Milky - Digital innovation                 /Milky                 Milky
# 29  Milky - Digital innovation                 /Milky                 Milky
# 30                Claire Jones             /hivernoir             hivernoir
# 31                Claire Jones             /hivernoir             hivernoir
# 32                Claire Jones             /hivernoir             hivernoir
# 33             Rodolfo Alvarez     /dg.rodolfoalvarez     dg.rodolfoalvarez
# 34               iconsmind.com               /imicons               imicons
# 35               iconsmind.com               /imicons               imicons
# 36                  Rohith M S          /rohithdezinr          rohithdezinr
# 37               Ricardo Mena           /ricardo_mena          ricardo_mena
# 38              Creative Stall         /creativestall         creativestall
# 39              Hadi Davodpour             /hadivoice             hadivoice
# 40      Ramakrishna Venkatesan         /RamakrishnaUX         RamakrishnaUX
# 41              Creative Stall         /creativestall         creativestall
# 42              Creative Stall         /creativestall         creativestall
# 43         Miguel C Balandrano            /balandrano            balandrano
# 44                    23 icons            /x09231986x            x09231986x
# 45                Antistatique          /antistatique          antistatique
# 46                 Peter Magdy               /Mangawy               Mangawy
# 47              Gregor Cresnar         /grega.cresnar         grega.cresnar
# 48              Jamie Rothwell      /jamiesonrothwell      jamiesonrothwell
# 49            Maurizio Fusillo       /fusillomaurizio       fusillomaurizio

# %% [markdown]
# ## Clean the empty data

# %%
# replace any empty strings in the 'location' column with np.nan objects
df['location'].replace('', np.nan, inplace=True)

# drop the null values:
df.dropna(subset=['location'], inplace=True)

df
# Out:
#                                              location  \
# 0                         New York City, New York, US
# 1                                          Moscow, RU
# 2                                          Moscow, RU
# 3                                 Los Angeles, CA, US
# 4                                lausanne, Suisse, CH
# 5                                  Berlin, Berlin, DE
# 6                                   Paris, France, FR
# 7                         Los Angeles, California, US
# 9                                                  US
# 11                                        Bangkok, TH
# 12                                      Edinburgh, GB
# 13                                                 BR
# 14                 Hemel Hempstead, Hertfordshire, GB
# 15                 Hemel Hempstead, Hertfordshire, GB
# 16                        Sydney, New South Wales, AU
# 17                            Mumbai, Maharashtra, IN
# 18                                Mobile, Alabama, US
# 22                                          İzmir, TR
# 23                        Olympia, WA, Washington, US
# 24                                      Edinburgh, GB
# 25                                          Sofia, BG
# 26                                  Paris, France, FR
# 27                                  Paris, France, FR
# 28                                  Paris, France, FR
# 29                                  Paris, France, FR
# 30                                      Edinburgh, GB
# 31                                      Edinburgh, GB
# 32                                      Edinburgh, GB
# 33                                     DF, México, MX
# 34                                         London, GB
# 35                                         London, GB
# 36                           Bangalore, Karnataka, IN
# 37                                         Madrid, ES
# 38                                 Lahore, Punjab, PK
# 39                                 Tehran, Tehran, IR
# 40                             Chennai, Tamilnadu, IN
# 41                                 Lahore, Punjab, PK
# 42                                 Lahore, Punjab, PK
# 43                          Monterrey, Nuevo León, MX
# 45                                       Lausanne, CH
# 46                                          cairo, EG
# 48  Vancouver (East Mount Pleasant), British Colum...
# 49                                     san severo, IT
#
#                           name              permalink              username
# 0                  OCHA Visual            /ochavisual            ochavisual
# 1                Anuar Zhumaev               /yxorama               yxorama
# 2                Anuar Zhumaev               /yxorama               yxorama
# 3            ✦ Shmidt Sergey ✦         /monstercritic         monstercritic
# 4            stephanie wauters     /Stephanie Wauters     Stephanie Wauters
# 5             Sebastian Langer  /sebastian.langer.330  sebastian.langer.330
# 6                  Rémy Médard             /catalarem             catalarem
# 7                  Matt Brooks           /Mattebrooks           Mattebrooks
# 9               Michael Loupos           /mikeydoesit           mikeydoesit
# 11          NATAPON CHANTABUTR                   /piq                   piq
# 12                Claire Jones             /hivernoir             hivernoir
# 13               Manuela Ribas             /manuribas             manuribas
# 14              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 15              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 16           Gosia Gasiorowski               /goshahh               goshahh
# 17                   Karthik M             /imkarthik             imkarthik
# 18               Alma Hoffmann                 /almah                 almah
# 22                     Doub.co                  /doub                  doub
# 23                  Luis Prado                  /Luis                  Luis
# 24                Claire Jones             /hivernoir             hivernoir
# 25             Stefan Parnarov                  /sapi                  sapi
# 26  Milky - Digital innovation                 /Milky                 Milky
# 27  Milky - Digital innovation                 /Milky                 Milky
# 28  Milky - Digital innovation                 /Milky                 Milky
# 29  Milky - Digital innovation                 /Milky                 Milky
# 30                Claire Jones             /hivernoir             hivernoir
# 31                Claire Jones             /hivernoir             hivernoir
# 32                Claire Jones             /hivernoir             hivernoir
# 33             Rodolfo Alvarez     /dg.rodolfoalvarez     dg.rodolfoalvarez
# 34               iconsmind.com               /imicons               imicons
# 35               iconsmind.com               /imicons               imicons
# 36                  Rohith M S          /rohithdezinr          rohithdezinr
# 37               Ricardo Mena           /ricardo_mena          ricardo_mena
# 38              Creative Stall         /creativestall         creativestall
# 39              Hadi Davodpour             /hadivoice             hadivoice
# 40      Ramakrishna Venkatesan         /RamakrishnaUX         RamakrishnaUX
# 41              Creative Stall         /creativestall         creativestall
# 42              Creative Stall         /creativestall         creativestall
# 43         Miguel C Balandrano            /balandrano            balandrano
# 45                Antistatique          /antistatique          antistatique
# 46                 Peter Magdy               /Mangawy               Mangawy
# 48              Jamie Rothwell      /jamiesonrothwell      jamiesonrothwell
# 49            Maurizio Fusillo       /fusillomaurizio       fusillomaurizio

# %% [markdown]
# ## Create a new column with country initials

# %%
#if need extract first 2 chars from each user
df['country_code'] = df.location.str[-2:]
df.sort_values(by='country_code', ascending=True, inplace=True)
df.reset_index(inplace=True, drop=True)

df['country_code'].value_counts()
# Out:
# GB    9
# US    6
# FR    5
# PK    3
# IN    3
# RU    2
# CH    2
# MX    2
# EG    1
# TH    1
# CA    1
# BG    1
# DE    1
# TR    1
# IR    1
# AU    1
# IT    1
# ES    1
# BR    1
# Name: country_code, dtype: int64

# %% [markdown]
# ## Create a new column with flag emoji based on initials

# %%
# create a list of our conditions
conditions = [
    (df['country_code'] == 'GB'),
    (df['country_code'] == 'US'),
    (df['country_code'] == 'FR'),
    (df['country_code'] == 'IN'),
    (df['country_code'] == 'PK'),
    (df['country_code'] == 'MX'),
    (df['country_code'] == 'RU'),
    (df['country_code'] == 'CH'),
    (df['country_code'] == 'EG'),
    (df['country_code'] == 'TH'),
    (df['country_code'] == 'IR'),
    (df['country_code'] == 'CA'),
    (df['country_code'] == 'TR'),
    (df['country_code'] == 'BR'),
    (df['country_code'] == 'ES'),
    (df['country_code'] == 'DE'),
    (df['country_code'] == 'AU'),
    (df['country_code'] == 'IT'),
    (df['country_code'] == 'BG'),
    ]

# create a list of the values we want to assign for each condition
values = ['🇬🇧', '🇺🇸', '🇫🇷', '🇮🇳', '🇵🇰', '🇲🇽', '🇷🇺', '🇨🇭', '🇪🇬', '🇹🇭', '🇮🇷', '🇨🇦', '🇹🇷', '🇧🇷', '🇪🇸', '🇩🇪', '🇦🇺', '🇮🇹', '🇧🇬']

df['country_emoji'] = np.select(conditions, values)

df
# Out:
#                                              location  \
# 0                         Sydney, New South Wales, AU
# 1                                           Sofia, BG
# 2                                                  BR
# 3   Vancouver (East Mount Pleasant), British Colum...
# 4                                        Lausanne, CH
# 5                                lausanne, Suisse, CH
# 6                                  Berlin, Berlin, DE
# 7                                           cairo, EG
# 8                                          Madrid, ES
# 9                                   Paris, France, FR
# 10                                  Paris, France, FR
# 11                                  Paris, France, FR
# 12                                  Paris, France, FR
# 13                                  Paris, France, FR
# 14                                      Edinburgh, GB
# 15                                      Edinburgh, GB
# 16                                         London, GB
# 17                 Hemel Hempstead, Hertfordshire, GB
# 18                                      Edinburgh, GB
# 19                 Hemel Hempstead, Hertfordshire, GB
# 20                                      Edinburgh, GB
# 21                                         London, GB
# 22                                      Edinburgh, GB
# 23                            Mumbai, Maharashtra, IN
# 24                           Bangalore, Karnataka, IN
# 25                             Chennai, Tamilnadu, IN
# 26                                 Tehran, Tehran, IR
# 27                                     san severo, IT
# 28                                     DF, México, MX
# 29                          Monterrey, Nuevo León, MX
# 30                                 Lahore, Punjab, PK
# 31                                 Lahore, Punjab, PK
# 32                                 Lahore, Punjab, PK
# 33                                         Moscow, RU
# 34                                         Moscow, RU
# 35                                        Bangkok, TH
# 36                                          İzmir, TR
# 37                                Mobile, Alabama, US
# 38                                                 US
# 39                        Los Angeles, California, US
# 40                                Los Angeles, CA, US
# 41                        Olympia, WA, Washington, US
# 42                        New York City, New York, US
#
#                           name              permalink              username  \
# 0            Gosia Gasiorowski               /goshahh               goshahh
# 1              Stefan Parnarov                  /sapi                  sapi
# 2                Manuela Ribas             /manuribas             manuribas
# 3               Jamie Rothwell      /jamiesonrothwell      jamiesonrothwell
# 4                 Antistatique          /antistatique          antistatique
# 5            stephanie wauters     /Stephanie Wauters     Stephanie Wauters
# 6             Sebastian Langer  /sebastian.langer.330  sebastian.langer.330
# 7                  Peter Magdy               /Mangawy               Mangawy
# 8                Ricardo Mena           /ricardo_mena          ricardo_mena
# 9   Milky - Digital innovation                 /Milky                 Milky
# 10  Milky - Digital innovation                 /Milky                 Milky
# 11                 Rémy Médard             /catalarem             catalarem
# 12  Milky - Digital innovation                 /Milky                 Milky
# 13  Milky - Digital innovation                 /Milky                 Milky
# 14                Claire Jones             /hivernoir             hivernoir
# 15                Claire Jones             /hivernoir             hivernoir
# 16               iconsmind.com               /imicons               imicons
# 17              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 18                Claire Jones             /hivernoir             hivernoir
# 19              Slawek Jurczyk         /slawekjurczyk         slawekjurczyk
# 20                Claire Jones             /hivernoir             hivernoir
# 21               iconsmind.com               /imicons               imicons
# 22                Claire Jones             /hivernoir             hivernoir
# 23                   Karthik M             /imkarthik             imkarthik
# 24                  Rohith M S          /rohithdezinr          rohithdezinr
# 25      Ramakrishna Venkatesan         /RamakrishnaUX         RamakrishnaUX
# 26              Hadi Davodpour             /hadivoice             hadivoice
# 27            Maurizio Fusillo       /fusillomaurizio       fusillomaurizio
# 28             Rodolfo Alvarez     /dg.rodolfoalvarez     dg.rodolfoalvarez
# 29         Miguel C Balandrano            /balandrano            balandrano
# 30              Creative Stall         /creativestall         creativestall
# 31              Creative Stall         /creativestall         creativestall
# 32              Creative Stall         /creativestall         creativestall
# 33               Anuar Zhumaev               /yxorama               yxorama
# 34               Anuar Zhumaev               /yxorama               yxorama
# 35          NATAPON CHANTABUTR                   /piq                   piq
# 36                     Doub.co                  /doub                  doub
# 37               Alma Hoffmann                 /almah                 almah
# 38              Michael Loupos           /mikeydoesit           mikeydoesit
# 39                 Matt Brooks           /Mattebrooks           Mattebrooks
# 40           ✦ Shmidt Sergey ✦         /monstercritic         monstercritic
# 41                  Luis Prado                  /Luis                  Luis
# 42                 OCHA Visual            /ochavisual            ochavisual
#
#    country_code country_emoji
# 0            AU            🇦🇺
# 1            BG            🇧🇬
# 2            BR            🇧🇷
# 3            CA            🇨🇦
# 4            CH            🇨🇭
# 5            CH            🇨🇭
# 6            DE            🇩🇪
# 7            EG            🇪🇬
# 8            ES            🇪🇸
# 9            FR            🇫🇷
# 10           FR            🇫🇷
# 11           FR            🇫🇷
# 12           FR            🇫🇷
# 13           FR            🇫🇷
# 14           GB            🇬🇧
# 15           GB            🇬🇧
# 16           GB            🇬🇧
# 17           GB            🇬🇧
# 18           GB            🇬🇧
# 19           GB            🇬🇧
# 20           GB            🇬🇧
# 21           GB            🇬🇧
# 22           GB            🇬🇧
# 23           IN            🇮🇳
# 24           IN            🇮🇳
# 25           IN            🇮🇳
# 26           IR            🇮🇷
# 27           IT            🇮🇹
# 28           MX            🇲🇽
# 29           MX            🇲🇽
# 30           PK            🇵🇰
# 31           PK            🇵🇰
# 32           PK            🇵🇰
# 33           RU            🇷🇺
# 34           RU            🇷🇺
# 35           TH            🇹🇭
# 36           TR            🇹🇷
# 37           US            🇺🇸
# 38           US            🇺🇸
# 39           US            🇺🇸
# 40           US            🇺🇸
# 41           US            🇺🇸
# 42           US            🇺🇸

# %% [markdown]
# ## Save as json for p5.js later

# %%
# df.to_csv('nounproject_countries.csv')
